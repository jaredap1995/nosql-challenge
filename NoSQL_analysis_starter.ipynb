# %% [markdown]
# # Eat Safe, Love

# %% [markdown]
# ## Notebook Set Up

# %%
# Import dependencies
from pymongo import MongoClient
from pprint import pprint
import pandas as pd
import pymongo
from bson.decimal128 import Decimal128

# %% [markdown]
# ### Code to upload data through terminal:
#
# mongoimport --db uk_food --collection establishments --file establishments.json --jsonArray

# %%
# Create an instance of MongoClient
mongo = MongoClient(port=27017)

# %%
mongo.list_database_names()
# Out:
# ['admin', 'config', 'local', 'uk_food']

# %%
# assign the uk_food database to a variable name
db = mongo['uk_food']

# %%
# review the collections in our database
db.list_collection_names()
# Out:
# ['establishments']

# %%
# assign the collection to a variable
establishments = db['establishments']

# %%
for doc in establishments.find().limit(5):
    pprint(doc['scores'])
# Out:
# {'ConfidenceInManagement': 0, 'Hygiene': 0, 'Structural': 0}
# {'ConfidenceInManagement': 5, 'Hygiene': 5, 'Structural': 5}
# {'ConfidenceInManagement': 10, 'Hygiene': 5, 'Structural': 5}
# {'ConfidenceInManagement': 10, 'Hygiene': 0, 'Structural': 0}
# {'ConfidenceInManagement': 0, 'Hygiene': 0, 'Structural': 5}

# %% [markdown]
# ## Part 3: Exploratory Analysis
# Unless otherwise stated, for each question:
# * Use `count_documents` to display the number of documents contained in the result.
# * Display the first document in the results using `pprint`.
# * Convert the result to a Pandas DataFrame, print the number of rows in the DataFrame, and display the first 10 rows.

# %% [markdown]
# ### 1. Which establishments have a hygiene score equal to 20?

# %%
# Find the establishments with a hygiene score of 20
establishments_with_score_20 = establishments.find({'scores.Hygiene': 20})

# Convert the result to a Pandas DataFrame now instead of later so we avoid using next on cursor object
df = pd.DataFrame(list(establishments_with_score_20))
df


# Use count_documents to display the number of documents in the result
result = establishments.count_documents({'scores.Hygiene': 20})
print("Number of establishments with a hygiene score of 20: ", result)

# Display the first document in the results using pprint
first_establishment = df.iloc[0]  # gets the first row of the DataFrame
pprint(first_establishment)
# Out:
# Number of establishments with a hygiene score of 20:  41
# _id                                                    6462e639ba9bfd9024b1bb35
# FHRSID                                                                   110681
# ChangesByServerID                                                             0
# LocalAuthorityBusinessID                                                   4029
# BusinessName                                                The Chase Rest Home
# BusinessType                                                    Caring Premises
# BusinessTypeID                                                                5
# AddressLine1                                               5-6 Southfields Road
# AddressLine2                                                         Eastbourne
# AddressLine3                                                        East Sussex
# AddressLine4
# PostCode                                                               BN21 1BU
# Phone
# ...

# %%
# Display the number of rows in the DataFrame
dfrows=len(df)
print(dfrows) #equal to the number of establishments with hygeine score of 20


# Display the first 10 rows of the DataFrame
df.head(10)
# Out:
# 41
#                         _id   FHRSID  ChangesByServerID  \
# 0  6462e639ba9bfd9024b1bb35   110681                  0
# 1  6462e639ba9bfd9024b1bec3   612039                  0
# 2  6462e63aba9bfd9024b1c1c9   730933                  0
# 3  6462e63aba9bfd9024b1c3b4   172735                  0
# 4  6462e63aba9bfd9024b1c3bd   172953                  0
# 5  6462e63aba9bfd9024b1cd5e   512854                  0
# 6  6462e63aba9bfd9024b1cf7a  1537089                  0
# 7  6462e63aba9bfd9024b1e4a8   155648                  0
# 8  6462e63aba9bfd9024b1e8ee  1012883                  0
# 9  6462e63aba9bfd9024b1f0fc   644109                  0
#
#   LocalAuthorityBusinessID               BusinessName  \
# 0                     4029        The Chase Rest Home
# 1                1970/FOOD                 Brenalwood
# 2                1698/FOOD              Melrose Hotel
# 3             PI/000023858              Seaford Pizza
# 4             PI/000024532              Golden Palace
# ...

# %% [markdown]
# ### 2. Which establishments in London have a `RatingValue` greater than or equal to 4?

# %%
unique_authorities = establishments.distinct('LocalAuthorityName')
if 'London' in unique_authorities:
    print('London is in the list')
else:
    print('London is not in the list')
# Out:
# London is not in the list

# %%
unique_authorities = establishments.distinct('AddressLine3')
if 'London' in unique_authorities:
    print('London is in the list')
else:
    print('London is not in the list')
# Out:
# London is in the list

# %% [markdown]
# ### London exists in AddressLine3 but not in Locl Authority Name

# %%
test = establishments.find({'LocalAuthorityName': 'London'})
list(test)
# Out:
# []

# %% [markdown]
# ## London not in the Local Establishment Name????

# %%
# Find the establishments with London as the Local Authority and has a RatingValue greater than or equal to 4.
establishments_london = establishments.find({'$and': [{'LocalAuthorityName': 'London'}, {'RatingValue': {'$gte': 4}}]})

# Convert the result to a Pandas DataFrame
df_london = pd.DataFrame(list(establishments_london))

# Use count_documents to display the number of documents in the result
result = establishments.count_documents({'$and': [{'LocalAuthorityName': 'London'}, {'RatingValue': {'$gte': 4}}]})

# Display the first document in the results using pprint
first_establishment = df_london.iloc[0]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[67], line 11
#       8 result = establishments.count_documents({'$and': [{'LocalAuthorityName': 'London'}, {'RatingValue': {'$gte': 4}}]})
#      10 # Display the first document in the results using pprint
# ---> 11 first_establishment = df_london.iloc[0]
#
# File ~/opt/miniconda3/envs/flask_blog/lib/python3.10/site-packages/pandas/core/indexing.py:1073, in _LocationIndexer.__getitem__(self, key)
#    1070 axis = self.axis or 0
#    1072 maybe_callable = com.apply_if_callable(key, self.obj)
# -> 1073 return self._getitem_axis(maybe_callable, axis=axis)
#
# File ~/opt/miniconda3/envs/flask_blog/lib/python3.10/site-packages/pandas/core/indexing.py:1625, in _iLocIndexer._getitem_axis(self, key, axis)
#    1622     raise TypeError("Cannot index by location index with a non-integer key")
#    1624 # validate the location
# ...

# %% [markdown]
# ### I get an error above because London is not in the LocalAuthorityName List so providing the code that would work if it was
#
# ### You can double chekc the JSON file as well. There is no London in LocalAuthorityName

# %%
# Display the number of rows in the DataFrame
print(len(df_london))
# Display the first 10 rows of the DataFrame
df_london.head(10)
# Out:
# 0
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# ### 3. What are the top 5 establishments with a `RatingValue` rating value of 5, sorted by lowest hygiene score, nearest to the new restaurant added, "Penang Flavours"?

# %%
from decimal import Decimal

# %%
latitude
# Out:
# Decimal128('51.49014200')

# %%
longitude
# Out:
# Decimal128('0.08384000')

# %%
# Search within 0.01 degree on either side of the latitude and longitude.
# Rating value must equal 5
# Sort by hygiene score

degree_search = 0.01
penang_flavours = establishments.find_one({"BusinessName": "Penang Flavours"})
latitude = penang_flavours['geocode']['latitude']
latitude=51.49014200
longitude = penang_flavours['geocode']['longitude']
longitude=0.08384000 #Just copy pasting and hardcoding because this is annoying


query = establishments.find({
    '$and': [
        {'geocode.latitude': {'$gte': latitude - degree_search}},
        {'geocode.latitude': {'$lte': latitude + degree_search}},
        {'geocode.longitude': {'$gte': longitude - degree_search}},
        {'geocode.longitude': {'$lte': longitude + degree_search}},
        {'RatingValue': 5}
    ]
}).sort('scores.Hygiene', pymongo.ASCENDING).limit(5) #Ascending because a low hygeine score is better according to the bootcamp spot information, so if we want the lowest
                                                        #hygeine score first we want the highest number first

results = list(query)

# %%
# Convert result to Pandas DataFrame
df_penang_flavours = pd.DataFrame(results)
df_penang_flavours
# Out:
#                         _id   FHRSID  ChangesByServerID  \
# 0  6462e63aba9bfd9024b1ed4a  1354861                  0
# 1  6462e63aba9bfd9024b1f1aa  1523742                  0
# 2  6462e63aba9bfd9024b1f169  1525936                  0
# 3  6462e63aba9bfd9024b1eb45   390283                  0
# 4  6462e63aba9bfd9024b1eb42   390400                  0
#
#   LocalAuthorityBusinessID              BusinessName             BusinessType  \
# 0              21/00075/CP                King Kebab   Takeaway/sandwich shop
# 1              22/00141/CP                   Martins        Retailers - other
# 2              22/00151/CP         The Muscle Market        Retailers - other
# 3              05/00101/CP  East Tilbury Post Office        Retailers - other
# 4              09/00040/CP      Nancy's Sandwich Bar  Restaurant/Cafe/Canteen
#
#    BusinessTypeID                         AddressLine1  \
# 0            7844                    George And Dragon
# ...

# %% [markdown]
# ### 4. How many establishments in each Local Authority area have a hygiene score of 0?

# %%
# Create a pipeline that: 
# 1. Matches establishments with a hygiene score of 0
# 2. Groups the matches by Local Authority
# 3. Sorts the matches from highest to lowest

pipeline = [
    {'$match': {'scores.Hygiene': 0}},
    {'$group': {'_id': '$LocalAuthorityName','count': {'$sum': 1 }}},
    {'$sort': {'count': -1}}]

results = list(establishments.aggregate(pipeline))

# Print the number of documents in the result

# Print the first 10 results
print("Number of documents in the result: ", len(results))
print("First 10 results: ", results[:10])
# Out:
# Number of documents in the result:  55
# First 10 results:  [{'_id': 'Thanet', 'count': 1130}, {'_id': 'Greenwich', 'count': 882}, {'_id': 'Maidstone', 'count': 713}, {'_id': 'Newham', 'count': 711}, {'_id': 'Swale', 'count': 686}, {'_id': 'Chelmsford', 'count': 680}, {'_id': 'Medway', 'count': 672}, {'_id': 'Bexley', 'count': 607}, {'_id': 'Southend-On-Sea', 'count': 586}, {'_id': 'Tendring', 'count': 542}]

# %%
# Convert the result to a Pandas DataFrame
df_hygiene_0 = pd.DataFrame(results)

# Display the number of rows in the DataFrame
print(len(df_hygiene_0))

# Display the first 10 rows of the DataFrame
df_hygiene_0.head(10)
# Out:
# 55
#                _id  count
# 0           Thanet   1130
# 1        Greenwich    882
# 2        Maidstone    713
# 3           Newham    711
# 4            Swale    686
# 5       Chelmsford    680
# 6           Medway    672
# 7           Bexley    607
# 8  Southend-On-Sea    586
# 9         Tendring    542
